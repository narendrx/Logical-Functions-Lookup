# %% [markdown]
# # Logical Functions & Lookup
#
#
# 1. Write a formula to check if the marks in cell 2 are greater than or equal to 40. If yes, return Puss", otherwise Fall
#      - Formula: =IF(B2>=40, "Pass", "Fail")
#        Logic: Checks if marks are 40 or higher.
#
# 2. A company gives a bonus if sales are above 40,000 and attendance is greater than or equal to 90%. Write a formula to calculate whether the employee will get a bonus or not.
#     - Formula: =IF(AND(B2>40000, C2>=90), "Bonus", "No Bonus")
#      logic: Both conditions (Sales > 40k and Attendance ≥ 90%) must be true.
#
# 3. 3. Write a nested IF formula:
#       if marks in B2 are 9027550, otherwise fall
#       - Formula: =IF(B2>=90, "A", IF(B2>=75, "B", IF(B2>=50, "C", "Fail")))
#       logic: Evaluates conditions in order from highest to lowest score.
#
# 4. Find the Department of Employee ID E103. Also explain which LOOKUP function is used and why?
#       - Formula: =VLOOKUP("E103", A2:C5, 3, 0)
#         function Used: VLOOKUP.
#         why: It searches for a value in the leftmost column and retrieves data from a specific column index (column 3) to the right.
#
# 5. A company has set the following commission structure for its sales team:
#        - Formula: =VLOOKUP(45000, A2:B5, 2, 1)
#          logic: Uses 1 (or TRUE) for an approximate match because 45,000 falls between the defined tiers (20,000 and 50,000).
#
# 6. The HR department maintains the following leave records of employees:onus or not
#         - Formula: =IF(B2>C2, "Exceeded", "OK")
#           logic: Compares "Leaves Taken" against "Leaves Allowed."
#
# 7. Find the salary of EmpID E105 using INDEX-MATCH Faction.
#         - Formula: =INDEX(B2:B5, MATCH("E105", A2:A5, 0))
#           logic: MATCH finds the row position of "E105," and INDEX retrieves the salary from that specific row.
#
# 8. Use the XLOOKUP function to find the Department of the employee with Emp ID 1303.
#         - Formula: =XLOOKUP("E303", A2:A5, B2:B5)
#           Note: The table header in the image says "Salary," but the question asks for "Department." This formula looks up the ID in the first column and returns the corresponding value from the second column.
